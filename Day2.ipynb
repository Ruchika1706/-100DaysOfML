# %%
#Read Data from Automobile Data Set, find mean of any column whose values are continuous
import pandas as pd
column = [25] #from the data given price is continous 
columns = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors:","body-style","drive-wheels",
"engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size",
"fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
temp = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data", header = None, skipinitialspace = True, names=columns)
#names = columns will assign these header names to the columns in the data
df = pd.DataFrame(data=temp)
#print(df.dtypes) #to print the data type of each column
#price is missing for certain rows in the data, so the data type is object here. Check in the data set, search for ?
# to print the number of missing value in print column
price = df['price'].tolist()
print(len(df.loc[df['price'] == '?'])) #Way1 to print the count of the rows where price value is missing in the data
count = 0
#df['price'].replace(to_replace='?',value='0')
df["price"] = df["price"].replace("?",0) #Alternative way to replace the ? to 0 in price column only
#df.loc[df['price'] == '?','price'] = '0' # to replace the ? to 0 in price column only
#df.loc[df['price'] == '?'] = '0' # IMP This will replace the entire row
print(len(df.loc[df['price'] == '?']))
print(df)
#print(df['price'])
#print(sum([count+1 for each in price if each == '?'])) #way2
#way3
for each in price:
    if each == '?':
        count+=1
#print(count) 


#temp #this renders the display in a better format than print(temp). Done by Jupyter
#values = temp[25].tolist()
#print(values)
#print(sum(values))

#print(pandas.DataFrame(columns=column))
#print(temp)
# Out:
# 4
# 0
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
#Read Data from Automobile Data Set, find mean of any column whose values are continuous
import pandas as pd
import numpy as np
column = [25] #from the data given price is continous 
columns = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors:","body-style","drive-wheels",
"engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size",
"fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
temp = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data", header = None, skipinitialspace = True, names=columns)
df = pd.DataFrame(data=temp)
df["price"] = df["price"].replace("?",0) #Alternative way to replace the ? to 0 in price column only
#print(df.dtypes)
df['price'] = pd.to_numeric(df['price'])
#print(df.dtypes)
print(df["price"].mean())
print(df['price'].replace(0, np.nan).mean())
price = df['price'].tolist()
price = list(map(int,price))
#print(sum(price)/len(price))
# Out:
# 12949.429268292683
# 13207.129353233831

# %%
#replace the missing value with the mean of other rows for the price column. 
import pandas as pd
columns = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors:","body-style","drive-wheels",
"engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size",
"fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
temp = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data", header = None, skipinitialspace = True, names=columns)
df = pd.DataFrame(data=temp)
#print(df['price'])
df["price"] = df["price"].replace("?",0)
df['price'] = pd.to_numeric(df['price'])
#print(df['price'].mean())
df['price'] = df['price'].replace(0,df['price'].mean())
print(df['price'])
# Out:
# 0      13495.000000
# 1      16500.000000
# 2      16500.000000
# 3      13950.000000
# 4      17450.000000
# 5      15250.000000
# 6      17710.000000
# 7      18920.000000
# 8      23875.000000
# 9      12949.429268
# 10     16430.000000
# 11     16925.000000
# 12     20970.000000
# 13     21105.000000
# 14     24565.000000
# 15     30760.000000
# 16     41315.000000
# 17     36880.000000
# 18      5151.000000
# 19      6295.000000
# 20      6575.000000
# 21      5572.000000
# 22      6377.000000
# 23      7957.000000
# 24      6229.000000
# 25      6692.000000
# 26      7609.000000
# 27      8558.000000
# 28      8921.000000
# 29     12964.000000
#            ...
# 175     9988.000000
# 176    10898.000000
# 177    11248.000000
# 178    16558.000000
# 179    15998.000000
# 180    15690.000000
# 181    15750.000000
# 182     7775.000000
# 183     7975.000000
# 184     7995.000000
# 185     8195.000000
# 186     8495.000000
# 187     9495.000000
# 188     9995.000000
# ...

# %%
#Find the difference in the mean of price of diesel cars and gas cars
import pandas as pd
columns = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors:","body-style","drive-wheels",
"engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size",
"fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
temp = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data", header = None, skipinitialspace = True, names=columns)
df = pd.DataFrame(data=temp)
df["price"] = df["price"].replace("?",0) # Replace missing value with 0
df['price'] = pd.to_numeric(df['price']) # convert the data type to numeric data type
df['price'].groupby(df['fuel-type']).mean() # group price column by fuel-type and calculate mean, output in series DS
print(type(df['price'].groupby(df['fuel-type']).mean())) # Series data type
print(df['price'].groupby(df['fuel-type']).mean()[0] - df['price'].groupby(df['fuel-type']).mean()[1]) #index to access series data structure elements
# Out:
# <class 'pandas.core.series.Series'>
# 3201.0148648648646
